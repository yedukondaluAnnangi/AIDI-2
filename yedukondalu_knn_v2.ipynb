# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data" , names = ["ID","Clump Thickness","UniofCellsize","UniCellShape","MarginalAdhesion","ESingle Epithelial Cell Size","Bare Nuclei","Bland Chromatin","Normal Nucleoli","Mitoses","Class"])

# %%
df
# Out:
#           ID  Clump Thickness  UniofCellsize  UniCellShape  MarginalAdhesion  \
# 0    1000025                5              1             1                 1
# 1    1002945                5              4             4                 5
# 2    1015425                3              1             1                 1
# 3    1016277                6              8             8                 1
# 4    1017023                4              1             1                 3
# ..       ...              ...            ...           ...               ...
# 694   776715                3              1             1                 1
# 695   841769                2              1             1                 1
# 696   888820                5             10            10                 3
# 697   897471                4              8             6                 4
# 698   897471                4              8             8                 5
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                              0
# Clump Thickness                 0
# UniofCellsize                   0
# UniCellShape                    0
# MarginalAdhesion                0
# ESingle Epithelial Cell Size    0
# Bare Nuclei                     0
# Bland Chromatin                 0
# Normal Nucleoli                 0
# Mitoses                         0
# Class                           0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                               int64
# Clump Thickness                  int64
# UniofCellsize                    int64
# UniCellShape                     int64
# MarginalAdhesion                 int64
# ESingle Epithelial Cell Size     int64
# Bare Nuclei                     object
# Bland Chromatin                  int64
# Normal Nucleoli                  int64
# Mitoses                          int64
# Class                            int64
# dtype: object

# %%
df['Bare Nuclei'].value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: Bare Nuclei, dtype: int64

# %%
df['Bare Nuclei'].replace('?','1', inplace =True)

# %%
df.corr()
# Out:
#                                     ID  Clump Thickness  UniofCellsize  \
# ID                            1.000000        -0.055308      -0.041603
# Clump Thickness              -0.055308         1.000000       0.644913
# UniofCellsize                -0.041603         0.644913       1.000000
# UniCellShape                 -0.041576         0.654589       0.906882
# MarginalAdhesion             -0.064878         0.486356       0.705582
# ESingle Epithelial Cell Size -0.045528         0.521816       0.751799
# Bland Chromatin              -0.060051         0.558428       0.755721
# Normal Nucleoli              -0.052072         0.535835       0.722865
# Mitoses                      -0.034901         0.350034       0.458693
# Class                        -0.080226         0.716001       0.817904
#
#                               UniCellShape  MarginalAdhesion  \
# ID                               -0.041576         -0.064878
# Clump Thickness                   0.654589          0.486356
# ...

# %%
data = np.random.random((5, 5))
plt.imshow(data, cmap='hot', interpolation='nearest')

plt.colorbar()
plt.show()

# %%
df.drop('UniCellShape', axis=1, inplace=True)

# %%
df.drop('ID', axis=1, inplace=True)

# %%
df
# Out:
#      Clump Thickness  UniofCellsize  MarginalAdhesion  \
# 0                  5              1                 1
# 1                  5              4                 5
# 2                  3              1                 1
# 3                  6              8                 1
# 4                  4              1                 3
# ..               ...            ...               ...
# 694                3              1                 1
# 695                2              1                 1
# 696                5             10                 3
# 697                4              8                 4
# 698                4              8                 5
#
#      ESingle Epithelial Cell Size Bare Nuclei  Bland Chromatin  \
# 0                               2           1                3
# 1                               7          10                3
# 2                               2           2                3
# ...

# %%
df.columns
# Out:
# Index(['Clump Thickness', 'UniofCellsize', 'MarginalAdhesion',
#        'ESingle Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
x=df[['Clump Thickness', 'UniofCellsize', 'MarginalAdhesion',
       'ESingle Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
       'Normal Nucleoli', 'Mitoses']]
y=df['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

model2 = KNeighborsClassifier(n_neighbors=5) 
model2.fit(X_train, y_train)
y_pred = model2.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9885714285714285
# C:\Users\nandi\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
